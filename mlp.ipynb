# %%
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.models import Sequential

import matplotlib.pyplot as plt

from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score
from sklearn.preprocessing import StandardScaler

from codecarbon import EmissionsTracker
# Out:
# 2025-01-23 11:54:13.902170: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-23 11:54:13.902525: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-23 11:54:13.904881: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-23 11:54:13.913665: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737644053.928158  136519 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737644053.931819  136519 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-23 11:54:13.946270: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('./final-data-pre-processed.csv', sep=',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145139 entries, 0 to 145138
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   DATA                                                   145139 non-null  object
#  1   HORA                                                   145139 non-null  object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       145139 non-null  float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  145139 non-null  float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        145139 non-null  float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       145139 non-null  float64
#  6   RADIACAO GLOBAL (KJ/m²)                                145139 non-null  float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           145139 non-null  float64
#  8   TEMPERATURA DO PONTO DE ORVALHO (°C)                   145139 non-null  float64
#  9   TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)             145139 non-null  float64
#  10  TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)             145139 non-null  float64
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)       145139 non-null  float64
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)       145139 non-null  float64
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               145139 non-null  float64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               145139 non-null  float64
#  15  UMIDADE RELATIVA DO AR, HORARIA (%)                    145139 non-null  float64
#  16  VENTO, DIREÇÃO HORARIA (gr) (° (gr))                   145139 non-null  float64
#  17  VENTO, RAJADA MAXIMA (m/s)                             145139 non-null  float64
#  18  VENTO, VELOCIDADE HORARIA (m/s)                        145139 non-null  float64
#  19  timestamp                                              145139 non-null  object
# dtypes: float64(17), object(3)
# memory usage: 22.1+ MB

# %%
X_prec = df[[
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (KJ/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_prec = df[['PRECIPITAÇÃO TOTAL, HORÁRIO (mm)']]

# %%
X_temp = df[[
       'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (KJ/m²)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 
       'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)'
    ]]

y_temp = df[['TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)']]

# %%
def split_train_test(X, y, train_size):
    X_train, X_test = X[:round(X.shape[0]*train_size)], X[round(X.shape[0]*train_size):]
    y_train, y_test = y[:round(y.shape[0]*train_size)], y[round(y.shape[0]*train_size):]

    return X_train, X_test, y_train, y_test

def plot_prediction_over_time(y_test, predictions, timestamps, start_date=None, end_date=None, save=False):
    timestamps = pd.to_datetime(timestamps)

    data = pd.DataFrame({
        'Timestamp': timestamps,
        'Actual': y_test,
        'Predicted': predictions
    })

    if start_date:
        data = data[data['Timestamp'] >= pd.to_datetime(start_date)]
    if end_date:
        data = data[data['Timestamp'] <= pd.to_datetime(end_date)]

    plt.figure(figsize=(12, 6))
    plt.plot(data['Timestamp'], data['Actual'], label='Actual Values', color='blue', linewidth=2)
    plt.plot(data['Timestamp'], data['Predicted'], label='Predicted Values', color='orange', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title('Actual vs. Predicted Values Over Time')
    plt.legend()
    plt.grid(True)

    
    if save: 
        plt.savefig(save)
        
    plt.show()


def plot_real_vs_predicted(y_test, predictions, save=False):
    plt.figure(figsize=(8, 8))
    plt.scatter(y_test, predictions, alpha=0.7, color='blue')
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--', color='red', linewidth=2, label="Ideal Fit")
    plt.xlabel("Actual Values")
    plt.ylabel("Predicted Values")
    plt.title("Real vs Predicted Values")
    plt.legend()
    plt.grid(True)

    if save: 
        plt.savefig(save)
    
    plt.show()

# %% [markdown]
# ## mlp temperature

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_temp)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_temp)

# %%
X_temp_train, X_temp_test, y_temp_train, y_temp_test = split_train_test(X_temp, y_temp, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_temp.shape[1], activation='relu', input_shape=(X_temp.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# /usr/share/jupyter/kernels/tf-p3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-01-23 10:10:43.887518: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
tracker = EmissionsTracker(
    project_name="mlp temperature train",
    output_file='./codecarbon_emissions.csv',
    log_level = "critical"
)

tracker.start()


model.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mean_absolute_error'] 
)

model.summary()

model.fit(X_temp_train, y_temp_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_temp_test, y_temp_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")


rmse = np.sqrt(loss)
print(f"Root Mean Squared Error (RMSE): {rmse}")


emissions: float = tracker.stop()
print(f"emissions={emissions}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549 (2.14 KB)
#  Trainable params: 549 (2.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 246.8932 - mean_absolute_error: 6.2692
# Epoch 2/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.5660 - mean_absolute_error: 2.3380
# Epoch 3/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 8.2020 - mean_absolute_error: 2.2950
# Epoch 4/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.7655 - mean_absolute_error: 2.2362
# Epoch 5/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.2382 - mean_absolute_error: 2.1638
# Epoch 6/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 7.0752 - mean_absolute_error: 2.1411
# Epoch 7/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.8845 - mean_absolute_error: 2.1122
# Epoch 8/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.8706 - mean_absolute_error: 2.1183
# Epoch 9/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.8939 - mean_absolute_error: 2.1183
# Epoch 10/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.7109 - mean_absolute_error: 2.0939
# Epoch 11/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.7558 - mean_absolute_error: 2.0994
# Epoch 12/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.7155 - mean_absolute_error: 2.0929
# Epoch 13/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.7460 - mean_absolute_error: 2.0997
# Epoch 14/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.7976 - mean_absolute_error: 2.1020
# Epoch 15/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6781 - mean_absolute_error: 2.0863
# Epoch 16/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6826 - mean_absolute_error: 2.0852
# Epoch 17/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6904 - mean_absolute_error: 2.0894
# Epoch 18/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 984us/step - loss: 6.6927 - mean_absolute_error: 2.0895
# Epoch 19/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 976us/step - loss: 6.6266 - mean_absolute_error: 2.0808
# Epoch 20/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6342 - mean_absolute_error: 2.0819
# Epoch 21/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6598 - mean_absolute_error: 2.0818
# Epoch 22/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6165 - mean_absolute_error: 2.0796
# Epoch 23/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 973us/step - loss: 6.6380 - mean_absolute_error: 2.0802
# Epoch 24/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 945us/step - loss: 6.6220 - mean_absolute_error: 2.0791
# Epoch 25/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 941us/step - loss: 6.5925 - mean_absolute_error: 2.0727
# Epoch 26/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1000us/step - loss: 6.6453 - mean_absolute_error: 2.0829
# Epoch 27/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5766 - mean_absolute_error: 2.0739
# Epoch 28/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 972us/step - loss: 6.5894 - mean_absolute_error: 2.0779
# Epoch 29/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6039 - mean_absolute_error: 2.0743
# Epoch 30/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.6149 - mean_absolute_error: 2.0779
# Epoch 31/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5822 - mean_absolute_error: 2.0722
# Epoch 32/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5582 - mean_absolute_error: 2.0697
# Epoch 33/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5543 - mean_absolute_error: 2.0679
# Epoch 34/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5370 - mean_absolute_error: 2.0666
# Epoch 35/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1000us/step - loss: 6.5803 - mean_absolute_error: 2.0737
# Epoch 36/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5267 - mean_absolute_error: 2.0621
# Epoch 37/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 992us/step - loss: 6.6067 - mean_absolute_error: 2.0782
# Epoch 38/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 989us/step - loss: 6.5583 - mean_absolute_error: 2.0694
# Epoch 39/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5524 - mean_absolute_error: 2.0669
# Epoch 40/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 976us/step - loss: 6.5214 - mean_absolute_error: 2.0656
# Epoch 41/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5396 - mean_absolute_error: 2.0673
# Epoch 42/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5071 - mean_absolute_error: 2.0602
# Epoch 43/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5335 - mean_absolute_error: 2.0659
# Epoch 44/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5647 - mean_absolute_error: 2.0706
# Epoch 45/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5771 - mean_absolute_error: 2.0724
# Epoch 46/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5017 - mean_absolute_error: 2.0617
# Epoch 47/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 993us/step - loss: 6.5048 - mean_absolute_error: 2.0601
# Epoch 48/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4971 - mean_absolute_error: 2.0600
# Epoch 49/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5226 - mean_absolute_error: 2.0623
# Epoch 50/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4650 - mean_absolute_error: 2.0546
# Epoch 51/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4943 - mean_absolute_error: 2.0600
# Epoch 52/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4793 - mean_absolute_error: 2.0552
# Epoch 53/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4886 - mean_absolute_error: 2.0575
# Epoch 54/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 964us/step - loss: 6.4712 - mean_absolute_error: 2.0605
# Epoch 55/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4504 - mean_absolute_error: 2.0529
# Epoch 56/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4791 - mean_absolute_error: 2.0582
# Epoch 57/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 984us/step - loss: 6.4594 - mean_absolute_error: 2.0557
# Epoch 58/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4572 - mean_absolute_error: 2.0527
# Epoch 59/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 960us/step - loss: 6.4513 - mean_absolute_error: 2.0546
# Epoch 60/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 995us/step - loss: 6.4453 - mean_absolute_error: 2.0534
# Epoch 61/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.5136 - mean_absolute_error: 2.0622
# Epoch 62/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 980us/step - loss: 6.4482 - mean_absolute_error: 2.0511
# Epoch 63/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 983us/step - loss: 6.4524 - mean_absolute_error: 2.0522
# Epoch 64/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 970us/step - loss: 6.4775 - mean_absolute_error: 2.0571
# Epoch 65/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4424 - mean_absolute_error: 2.0522
# Epoch 66/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4539 - mean_absolute_error: 2.0511
# Epoch 67/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 999us/step - loss: 6.4610 - mean_absolute_error: 2.0531
# Epoch 68/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4442 - mean_absolute_error: 2.0473
# Epoch 69/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4642 - mean_absolute_error: 2.0554
# Epoch 70/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4904 - mean_absolute_error: 2.0586
# Epoch 71/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4608 - mean_absolute_error: 2.0545
# Epoch 72/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4192 - mean_absolute_error: 2.0509
# Epoch 73/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4481 - mean_absolute_error: 2.0509
# Epoch 74/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4307 - mean_absolute_error: 2.0514
# Epoch 75/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4087 - mean_absolute_error: 2.0454
# Epoch 76/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3888 - mean_absolute_error: 2.0449
# Epoch 77/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3983 - mean_absolute_error: 2.0429
# Epoch 78/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3785 - mean_absolute_error: 2.0407
# Epoch 79/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4283 - mean_absolute_error: 2.0513
# Epoch 80/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 995us/step - loss: 6.4214 - mean_absolute_error: 2.0480
# Epoch 81/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 983us/step - loss: 6.4233 - mean_absolute_error: 2.0524
# Epoch 82/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 958us/step - loss: 6.3876 - mean_absolute_error: 2.0451
# Epoch 83/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 966us/step - loss: 6.4403 - mean_absolute_error: 2.0519
# Epoch 84/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 949us/step - loss: 6.4466 - mean_absolute_error: 2.0517
# Epoch 85/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 947us/step - loss: 6.4331 - mean_absolute_error: 2.0505
# Epoch 86/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4233 - mean_absolute_error: 2.0485
# Epoch 87/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 994us/step - loss: 6.4042 - mean_absolute_error: 2.0468
# Epoch 88/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 957us/step - loss: 6.4139 - mean_absolute_error: 2.0471
# Epoch 89/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 948us/step - loss: 6.4154 - mean_absolute_error: 2.0464
# Epoch 90/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 3s 954us/step - loss: 6.3914 - mean_absolute_error: 2.0473
# Epoch 91/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4324 - mean_absolute_error: 2.0500
# Epoch 92/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3769 - mean_absolute_error: 2.0405
# Epoch 93/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3800 - mean_absolute_error: 2.0433
# Epoch 94/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3850 - mean_absolute_error: 2.0420
# Epoch 95/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3968 - mean_absolute_error: 2.0427
# Epoch 96/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3876 - mean_absolute_error: 2.0423
# Epoch 97/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4024 - mean_absolute_error: 2.0445
# Epoch 98/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4205 - mean_absolute_error: 2.0469
# Epoch 99/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.4074 - mean_absolute_error: 2.0474
# Epoch 100/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 6.3767 - mean_absolute_error: 2.0427
# 908/908 - 1s - 889us/step - loss: 6.0552 - mean_absolute_error: 1.9857
# Loss (MSE): 6.055166244506836
# Mean Absolute Error: 1.9856964349746704
# Root Mean Squared Error (RMSE): 2.460724739686834
# emissions=0.0001757404560945155

# %%
y_temp_pred_probs = model.predict(X_temp_test, verbose=2)
# Out:
# 908/908 - 1s - 563us/step

# %%
y_temp_test_flat = y_temp_test.values.flatten()
y_temp_pred_flat = y_temp_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_temp_test_flat, y_temp_pred_flat, save='./images/models/mlp_temp_real_x_pred.png')

# %%
start_date = "2023-01-01"
end_date = "2023-01-30"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["timestamp"]

plot_prediction_over_time(y_temp_test_flat, y_temp_pred_flat, timestamps_test, start_date, end_date, save='./images/models/mlp_temp_over_time.png')

# %% [markdown]
# ## mlp precipitation

# %%
scaler_X = StandardScaler()
X_temp_normalized = scaler_X.fit_transform(X_prec)

scaler_y = StandardScaler()
y_temp_normalized = scaler_y.fit_transform(y_prec)

# %%
X_prec_train, X_prec_test, y_prec_train, y_prec_test = split_train_test(X_prec, y_prec, train_size=0.8)

# %%
model = tf.keras.Sequential([
    Dense(X_prec.shape[1], activation='relu', input_shape=(X_prec.shape[1], )),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')
])
# Out:
# /usr/share/jupyter/kernels/tf-p3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-01-23 11:54:22.491582: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
tracker = EmissionsTracker(
    project_name="mlp precipitation train",
    output_file='./codecarbon_emissions.csv',
    log_level = "critical"
)

tracker.start()

model.compile(
    loss='mean_squared_error', 
    optimizer='adam',
    metrics=['mean_absolute_error']  
)

model.summary()

model.fit(X_prec_train, y_prec_train, epochs=100, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_prec_test, y_prec_test, verbose=2)
print(f"Loss (MSE): {loss}")
print(f"Mean Absolute Error: {mae}")
# Out:
# [codecarbon ERROR @ 11:54:25] Error: Another instance of codecarbon is probably running as we find `/tmp/.codecarbon.lock`. Turn off the other instance to be able to run this one or use `allow_multiple_runs` or delete the file. Exiting.
# [codecarbon WARNING @ 11:54:25] Another instance of codecarbon is already running. Exiting.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 849 (3.32 KB)
#  Trainable params: 849 (3.32 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 3629/3629 ━━━━━━━━━━━━━━━━━━━━ 4s 982us/step - loss: 279.5321 - mean_absolute_error: 4.8572
# Epoch 2/100
# 2163/3629 ━━━━━━━━━━━━━━━━━━━━ 1s 957us/step - loss: 2.3815 - mean_absolute_error: 0.7830

# %%
y_prec_pred_probs = model.predict(X_prec_test, verbose=2)
# Out:
# 908/908 - 0s - 534us/step

# %%
y_prec_test_flat = y_prec_test.values.flatten()
y_prec_pred_flat = y_prec_pred_probs.flatten()

# %%
plot_real_vs_predicted(y_prec_test_flat, y_prec_pred_flat, save='./images/models/mlp_prec_real_x_pred.png')

# %%
start_date = "2023-01-01"
end_date = "2023-01-30"

timestamps_test = df.iloc[round(df.shape[0] * 0.8):]["timestamp"]

plot_prediction_over_time(y_prec_test_flat, y_prec_pred_flat, timestamps_test, start_date, end_date,  save='./images/models/mlp_prec_over_time.png')
