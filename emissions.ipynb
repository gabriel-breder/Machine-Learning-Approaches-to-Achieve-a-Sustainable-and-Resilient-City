# %%
import pandas as pd

# %%
df = pd.read_csv('codecarbon_emissions.csv')
df_lstm = pd.read_csv('codecarbon_emissions_cnn_lstm.csv')

# %%
df.columns
# Out:
# Index(['timestamp', 'project_name', 'run_id', 'experiment_id', 'duration',
#        'emissions', 'emissions_rate', 'cpu_power', 'gpu_power', 'ram_power',
#        'cpu_energy', 'gpu_energy', 'ram_energy', 'energy_consumed',
#        'country_name', 'country_iso_code', 'region', 'cloud_provider',
#        'cloud_region', 'os', 'python_version', 'codecarbon_version',
#        'cpu_count', 'cpu_model', 'gpu_count', 'gpu_model', 'longitude',
#        'latitude', 'ram_total_size', 'tracking_mode', 'on_cloud', 'pue'],
#       dtype='object')

# %%
df[['timestamp', 'project_name', 'duration', 'emissions', 'energy_consumed', 'cpu_model', 'ram_total_size', 'gpu_model']]
# Out:
#              timestamp                      project_name     duration  \
# 0  2025-01-22T19:56:37  xgboost precipiptation train 0.8   295.014616
# 1  2025-01-22T20:05:48  xgboost precipiptation train 0.8   175.596537
# 2  2025-01-22T20:28:50     xgboost temperature train 0.8   189.479080
# 3  2025-01-22T21:05:50     xgboost temperature train 0.8    94.900510
# 4  2025-01-22T22:08:12  xgboost precipiptation train 0.8   100.666647
# 5  2025-01-23T00:48:39        cnn-lstm temperature train  1155.682307
# 6  2025-01-23T01:15:40        cnn-lstm temperature train   116.381308
# 7  2025-01-23T01:48:56        cnn-lstm temperature train   164.838970
# 8  2025-01-23T10:17:14             mlp temperature train   384.793125
# 9  2025-01-23T12:38:02   cnn-lstm TEMPERATURE train TEST   118.094508
#
#    emissions  energy_consumed                                  cpu_model  \
# 0   0.000135         0.001370  Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz
# ...

# %%
df_lstm[['timestamp', 'project_name', 'duration', 'emissions', 'energy_consumed', 'cpu_model', 'ram_total_size', 'gpu_model']]
# Out:
#              timestamp                     project_name     duration  \
# 0  2025-01-23T13:32:12    CNN LSTM EMISSION TEMPERATURE     0.001537
# 1  2025-01-23T13:54:48  CNN LSTM EMISSION PRECIPITATION  1331.042335
# 2  2025-01-23T14:21:07    CNN LSTM EMISSION TEMPERATURE  1192.833189
#
#       emissions  energy_consumed                                  cpu_model  \
# 0  6.103445e-10     6.205968e-09  Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz
# 1  6.079084e-04     6.181197e-03  Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz
# 2  5.447868e-04     5.539378e-03  Intel(R) Core(TM) i7-1065G7 CPU @ 1.30GHz
#
#    ram_total_size  gpu_model
# 0       11.248306        NaN
# 1       11.248306        NaN
# 2       11.248306        NaN
